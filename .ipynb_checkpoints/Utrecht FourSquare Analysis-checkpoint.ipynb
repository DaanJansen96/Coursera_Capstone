# %% [markdown]
# The effect of hospitality on house prices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# Limitations: centroid location, but can be a good think.
#
# disregard for natural barriers i.e. water.
#
# disregard for public transport
#
# api limitations: maximum return of 100 venues per coordinate. due to this limitation i had to lower the search radius from 2km (ideal) to 0.5km.

# %% [markdown]
# # loading Neighbourhood data for the city of Utrecht

# %%
Neighbourhoods_netherlands = pd.read_csv("D:\\Coursera_Capstone\\WijkenEnBuurten2020.csv")
Neighbourhoods_netherlands['Codering_3']=Neighbourhoods_netherlands['Codering_3'].apply(lambda x : x.rstrip())
Neighbourhoods_netherlands['Gemeentenaam_1']=Neighbourhoods_netherlands['Gemeentenaam_1'].apply(lambda x : x.rstrip())
Neighbourhoods_netherlands['SoortRegio_2']=Neighbourhoods_netherlands['SoortRegio_2'].apply(lambda x : x.rstrip())

Neighbourhoods_prep = Neighbourhoods_netherlands[(Neighbourhoods_netherlands['Gemeentenaam_1']=='Utrecht')& (Neighbourhoods_netherlands['SoortRegio_2']=='Wijk')]
Neighbourhoods_prep = Neighbourhoods_prep.reset_index(drop=True)
Neighbourhoods_prep
# Out:
#       ID           WijkenEnBuurten Gemeentenaam_1 SoortRegio_2 Codering_3  \
# 0  14564              Wijk 01 West        Utrecht         Wijk   WK034401
# 1  14576         Wijk 02 Noordwest        Utrecht         Wijk   WK034402
# 2  14590         Wijk 03 Overvecht        Utrecht         Wijk   WK034403
# 3  14601         Wijk 04 Noordoost        Utrecht         Wijk   WK034404
# 4  14613              Wijk 05 Oost        Utrecht         Wijk   WK034405
# 5  14627        Wijk 06 Binnenstad        Utrecht         Wijk   WK034406
# 6  14639              Wijk 07 Zuid        Utrecht         Wijk   WK034407
# 7  14648          Wijk 08 Zuidwest        Utrecht         Wijk   WK034408
# 8  14656     Wijk 09 Leidsche Rijn        Utrecht         Wijk   WK034409
# 9  14672  Wijk 10 Vleuten-De Meern        Utrecht         Wijk   WK034410
#
#   IndelingswijzigingWijkenEnBuurten_4  AantalInwoners_5  Mannen_6  Vrouwen_7  \
# 0                                   1             29270     14210      15055
# 1                                   1             45255     22060      23195
# 2                                   1             34295     17200      17095
# 3                                   1             39680     18780      20895
# 4                                   1             32080     14905      17170
# 5                                   1             19165      9815       9345
# 6                                   1             27895     13685      14210
# 7                                   1             38620     19430      19190
# 8                                   1             41290     20685      20605
# 9                                   1             49795     24465      25330
#
#    k_0Tot15Jaar_8  ...  AfstandTotKinderdagverblijf_107  AfstandTotSchool_108  \
# 0            4600  ...                              0.3                   NaN
# 1            6240  ...                              0.3                   NaN
# 2            6425  ...                              0.4                   NaN
# 3            6215  ...                              0.3                   NaN
# 4            3450  ...                              0.4                   NaN
# 5             950  ...                              0.3                   NaN
# 6            4445  ...                              0.5                   NaN
# 7            6095  ...                              0.4                   NaN
# 8           10170  ...                              0.5                   NaN
# 9           11890  ...                              0.6                   NaN
#
#    ScholenBinnen3Km_109  OppervlakteTotaal_110  OppervlakteLand_111  \
# 0                   NaN                    898                  810
# 1                   NaN                    453                  440
# 2                   NaN                    848                  818
# 3                   NaN                    507                  498
# 4                   NaN                   1104                 1074
# 5                   NaN                    271                  260
# 6                   NaN                    473                  459
# 7                   NaN                    555                  506
# 8                   NaN                   1126                 1047
# 9                   NaN                   3685                 3471
#
#    OppervlakteWater_112  MeestVoorkomendePostcode_113  Dekkingspercentage_114  \
# 0                    88                             .                     NaN
# 1                    14                             .                     NaN
# 2                    30                             .                     NaN
# 3                     9                             .                     NaN
# 4                    30                             .                     NaN
# 5                    11                             .                     NaN
# 6                    14                             .                     NaN
# 7                    49                             .                     NaN
# 8                    79                             .                     NaN
# 9                   214                             .                     NaN
#
#    MateVanStedelijkheid_115  Omgevingsadressendichtheid_116
# 0                       1.0                          3707.0
# 1                       1.0                          4030.0
# 2                       1.0                          3276.0
# 3                       1.0                          4531.0
# 4                       1.0                          3545.0
# 5                       1.0                          5642.0
# 6                       1.0                          3263.0
# 7                       1.0                          3555.0
# 8                       2.0                          1958.0
# 9                       2.0                          1501.0
#
# [10 rows x 118 columns]

# %% [markdown]
# # loading Housing data for the city of Utrecht

# %%
url = "https://www.utrecht-monitor.nl/fysieke-leefomgeving/wonen/koopwoningmarkt#:~:text=Appartementen%20waren%20het%20duurst%20in,4.866%2C%2D%20per%20m2)."
html_scrape = pd.read_html(url)
Prices = html_scrape[1]
Prices.iloc[0,0]= 'Neighbourhood'
Prices.columns = Prices.iloc[0]
Prices = Prices[1:]
Prices = Prices.reset_index(drop=True)
Prices = Prices.drop(Prices.columns[[1, 2]], axis=1) 
Prices.rename(columns = {'transactieprijs2019-Q3' : 'Price_2019Q3', 'prijs / m22019-Q3' : 'Price_per_m2'}, inplace = True)
Prices
# Out:
# 0     Neighbourhood Price_2019Q3 Price_per_m2
# 0              West      341.181        4.219
# 1         Noordwest      309.690        4.015
# 2         Overvecht      274.954        2.908
# 3         Noordoost      445.016        4.788
# 4              Oost      507.770        4.887
# 5        Binnenstad      434.747        5.091
# 6              Zuid      327.887        3.802
# 7          Zuidwest      313.324        3.661
# 8     Leidsche rijn      415.235        3.673
# 9  Vleuten-De Meern      428.002        3.562

# %% [markdown]
# # Joining the datasets

# %%
Neighbourhoods = pd.merge(Neighbourhoods_prep, Prices, left_index=True, right_index=True)
Neighbourhoods
# Out:
#       ID           WijkenEnBuurten Gemeentenaam_1 SoortRegio_2 Codering_3  \
# 0  14564              Wijk 01 West        Utrecht         Wijk   WK034401
# 1  14576         Wijk 02 Noordwest        Utrecht         Wijk   WK034402
# 2  14590         Wijk 03 Overvecht        Utrecht         Wijk   WK034403
# 3  14601         Wijk 04 Noordoost        Utrecht         Wijk   WK034404
# 4  14613              Wijk 05 Oost        Utrecht         Wijk   WK034405
# 5  14627        Wijk 06 Binnenstad        Utrecht         Wijk   WK034406
# 6  14639              Wijk 07 Zuid        Utrecht         Wijk   WK034407
# 7  14648          Wijk 08 Zuidwest        Utrecht         Wijk   WK034408
# 8  14656     Wijk 09 Leidsche Rijn        Utrecht         Wijk   WK034409
# 9  14672  Wijk 10 Vleuten-De Meern        Utrecht         Wijk   WK034410
#
#   IndelingswijzigingWijkenEnBuurten_4  AantalInwoners_5  Mannen_6  Vrouwen_7  \
# 0                                   1             29270     14210      15055
# 1                                   1             45255     22060      23195
# 2                                   1             34295     17200      17095
# 3                                   1             39680     18780      20895
# 4                                   1             32080     14905      17170
# 5                                   1             19165      9815       9345
# 6                                   1             27895     13685      14210
# 7                                   1             38620     19430      19190
# 8                                   1             41290     20685      20605
# 9                                   1             49795     24465      25330
#
#    k_0Tot15Jaar_8  ...  OppervlakteTotaal_110  OppervlakteLand_111  \
# 0            4600  ...                    898                  810
# 1            6240  ...                    453                  440
# 2            6425  ...                    848                  818
# 3            6215  ...                    507                  498
# 4            3450  ...                   1104                 1074
# 5             950  ...                    271                  260
# 6            4445  ...                    473                  459
# 7            6095  ...                    555                  506
# 8           10170  ...                   1126                 1047
# 9           11890  ...                   3685                 3471
#
#    OppervlakteWater_112  MeestVoorkomendePostcode_113  Dekkingspercentage_114  \
# 0                    88                             .                     NaN
# 1                    14                             .                     NaN
# 2                    30                             .                     NaN
# 3                     9                             .                     NaN
# 4                    30                             .                     NaN
# 5                    11                             .                     NaN
# 6                    14                             .                     NaN
# 7                    49                             .                     NaN
# 8                    79                             .                     NaN
# 9                   214                             .                     NaN
#
#    MateVanStedelijkheid_115  Omgevingsadressendichtheid_116     Neighbourhood  \
# 0                       1.0                          3707.0              West
# 1                       1.0                          4030.0         Noordwest
# 2                       1.0                          3276.0         Overvecht
# 3                       1.0                          4531.0         Noordoost
# 4                       1.0                          3545.0              Oost
# 5                       1.0                          5642.0        Binnenstad
# 6                       1.0                          3263.0              Zuid
# 7                       1.0                          3555.0          Zuidwest
# 8                       2.0                          1958.0     Leidsche rijn
# 9                       2.0                          1501.0  Vleuten-De Meern
#
#    Price_2019Q3  Price_per_m2
# 0       341.181         4.219
# 1       309.690         4.015
# 2       274.954         2.908
# 3       445.016         4.788
# 4       507.770         4.887
# 5       434.747         5.091
# 6       327.887         3.802
# 7       313.324         3.661
# 8       415.235         3.673
# 9       428.002         3.562
#
# [10 rows x 121 columns]

# %% [markdown]
# # Cleaning
# 1. drop columns
# 2. change data types

# %%
Neighbourhoods = Neighbourhoods.drop(labels=['ID', 
                            'Gemeentenaam_1', 
                            'IndelingswijzigingWijkenEnBuurten_4', 
                            'MeestVoorkomendePostcode_113', 
                            'Dekkingspercentage_114'],
                    axis=1)

Neighbourhoods[["AantalInwoners_5", "Mannen_6", "Vrouwen_7", "k_0Tot15Jaar_8", "OppervlakteTotaal_110", "OppervlakteLand_111", "OppervlakteWater_112", "Omgevingsadressendichtheid_116", "Price_2019Q3", "Price_per_m2"]] = Neighbourhoods[["AantalInwoners_5", "Mannen_6", "Vrouwen_7", "k_0Tot15Jaar_8", "OppervlakteTotaal_110", "OppervlakteLand_111", "OppervlakteWater_112", "Omgevingsadressendichtheid_116", "Price_2019Q3", "Price_per_m2"]].apply(pd.to_numeric)
Neighbourhoods
# Out:
#             WijkenEnBuurten SoortRegio_2 Codering_3  AantalInwoners_5  \
# 0              Wijk 01 West         Wijk   WK034401             29270
# 1         Wijk 02 Noordwest         Wijk   WK034402             45255
# 2         Wijk 03 Overvecht         Wijk   WK034403             34295
# 3         Wijk 04 Noordoost         Wijk   WK034404             39680
# 4              Wijk 05 Oost         Wijk   WK034405             32080
# 5        Wijk 06 Binnenstad         Wijk   WK034406             19165
# 6              Wijk 07 Zuid         Wijk   WK034407             27895
# 7          Wijk 08 Zuidwest         Wijk   WK034408             38620
# 8     Wijk 09 Leidsche Rijn         Wijk   WK034409             41290
# 9  Wijk 10 Vleuten-De Meern         Wijk   WK034410             49795
#
#    Mannen_6  Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  k_25Tot45Jaar_10  \
# 0     14210      15055            4600             4215             12025
# 1     22060      23195            6240             6390             19595
# 2     17200      17095            6425             4410             11095
# 3     18780      20895            6215             6585             13480
# 4     14905      17170            3450             8270             11270
# 5      9815       9345             950             3255              9275
# 6     13685      14210            4445             4105             10265
# 7     19430      19190            6095             5730             15565
# 8     20685      20605           10170             4045             15755
# 9     24465      25330           11890             5660             12865
#
#    k_45Tot65Jaar_11  ...  AfstandTotSchool_108  ScholenBinnen3Km_109  \
# 0              5720  ...                   NaN                   NaN
# 1              8545  ...                   NaN                   NaN
# 2              7490  ...                   NaN                   NaN
# 3              9140  ...                   NaN                   NaN
# 4              5835  ...                   NaN                   NaN
# 5              3635  ...                   NaN                   NaN
# 6              6090  ...                   NaN                   NaN
# 7              7245  ...                   NaN                   NaN
# 8              8705  ...                   NaN                   NaN
# 9             13430  ...                   NaN                   NaN
#
#    OppervlakteTotaal_110  OppervlakteLand_111  OppervlakteWater_112  \
# 0                    898                  810                    88
# 1                    453                  440                    14
# 2                    848                  818                    30
# 3                    507                  498                     9
# 4                   1104                 1074                    30
# 5                    271                  260                    11
# 6                    473                  459                    14
# 7                    555                  506                    49
# 8                   1126                 1047                    79
# 9                   3685                 3471                   214
#
#    MateVanStedelijkheid_115  Omgevingsadressendichtheid_116     Neighbourhood  \
# 0                       1.0                          3707.0              West
# 1                       1.0                          4030.0         Noordwest
# 2                       1.0                          3276.0         Overvecht
# 3                       1.0                          4531.0         Noordoost
# 4                       1.0                          3545.0              Oost
# 5                       1.0                          5642.0        Binnenstad
# 6                       1.0                          3263.0              Zuid
# 7                       1.0                          3555.0          Zuidwest
# 8                       2.0                          1958.0     Leidsche rijn
# 9                       2.0                          1501.0  Vleuten-De Meern
#
#    Price_2019Q3  Price_per_m2
# 0       341.181         4.219
# 1       309.690         4.015
# 2       274.954         2.908
# 3       445.016         4.788
# 4       507.770         4.887
# 5       434.747         5.091
# 6       327.887         3.802
# 7       313.324         3.661
# 8       415.235         3.673
# 9       428.002         3.562
#
# [10 rows x 116 columns]

# %% [markdown]
# # Adding addtional columns
# 1. children density
# 2. average area of dwelling (square meters)

# %%
Neighbourhoods['children_density'] = Neighbourhoods['k_0Tot15Jaar_8']/Neighbourhoods['AantalInwoners_5']
Neighbourhoods['square_meters_2019'] = Neighbourhoods['Price_2019Q3']/Neighbourhoods['Price_per_m2']
Neighbourhoods
# Out:
#             WijkenEnBuurten SoortRegio_2 Codering_3  AantalInwoners_5  \
# 0              Wijk 01 West         Wijk   WK034401             29270
# 1         Wijk 02 Noordwest         Wijk   WK034402             45255
# 2         Wijk 03 Overvecht         Wijk   WK034403             34295
# 3         Wijk 04 Noordoost         Wijk   WK034404             39680
# 4              Wijk 05 Oost         Wijk   WK034405             32080
# 5        Wijk 06 Binnenstad         Wijk   WK034406             19165
# 6              Wijk 07 Zuid         Wijk   WK034407             27895
# 7          Wijk 08 Zuidwest         Wijk   WK034408             38620
# 8     Wijk 09 Leidsche Rijn         Wijk   WK034409             41290
# 9  Wijk 10 Vleuten-De Meern         Wijk   WK034410             49795
#
#    Mannen_6  Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  k_25Tot45Jaar_10  \
# 0     14210      15055            4600             4215             12025
# 1     22060      23195            6240             6390             19595
# 2     17200      17095            6425             4410             11095
# 3     18780      20895            6215             6585             13480
# 4     14905      17170            3450             8270             11270
# 5      9815       9345             950             3255              9275
# 6     13685      14210            4445             4105             10265
# 7     19430      19190            6095             5730             15565
# 8     20685      20605           10170             4045             15755
# 9     24465      25330           11890             5660             12865
#
#    k_45Tot65Jaar_11  ...  OppervlakteTotaal_110  OppervlakteLand_111  \
# 0              5720  ...                    898                  810
# 1              8545  ...                    453                  440
# 2              7490  ...                    848                  818
# 3              9140  ...                    507                  498
# 4              5835  ...                   1104                 1074
# 5              3635  ...                    271                  260
# 6              6090  ...                    473                  459
# 7              7245  ...                    555                  506
# 8              8705  ...                   1126                 1047
# 9             13430  ...                   3685                 3471
#
#    OppervlakteWater_112  MateVanStedelijkheid_115  \
# 0                    88                       1.0
# 1                    14                       1.0
# 2                    30                       1.0
# 3                     9                       1.0
# 4                    30                       1.0
# 5                    11                       1.0
# 6                    14                       1.0
# 7                    49                       1.0
# 8                    79                       2.0
# 9                   214                       2.0
#
#    Omgevingsadressendichtheid_116     Neighbourhood  Price_2019Q3  \
# 0                          3707.0              West       341.181
# 1                          4030.0         Noordwest       309.690
# 2                          3276.0         Overvecht       274.954
# 3                          4531.0         Noordoost       445.016
# 4                          3545.0              Oost       507.770
# 5                          5642.0        Binnenstad       434.747
# 6                          3263.0              Zuid       327.887
# 7                          3555.0          Zuidwest       313.324
# 8                          1958.0     Leidsche rijn       415.235
# 9                          1501.0  Vleuten-De Meern       428.002
#
#    Price_per_m2  children_density  square_meters_2019
# 0         4.219          0.157157           80.867741
# 1         4.015          0.137885           77.133250
# 2         2.908          0.187345           94.550894
# 3         4.788          0.156628           92.944027
# 4         4.887          0.107544          103.902189
# 5         5.091          0.049570           85.395207
# 6         3.802          0.159348           86.240663
# 7         3.661          0.157820           85.584267
# 8         3.673          0.246307          113.050640
# 9         3.562          0.238779          120.157777
#
# [10 rows x 118 columns]

# %% [markdown]
# # Adding coordinates of neighbourhoods

# %%
latitude = [52.1091, 52.1108, 52.1180, 52.1035, 52.0840, 52.0889, 52.0641, 52.0758, 52.0954, 52.1002]
longitude = [5.0668, 5.0902, 5.1080, 5.1351, 5.1547, 5.1175, 5.1245, 5.1003, 5.0457, 5.0021]
lat = np.asarray(latitude)
long = np.asarray(longitude)
Neighbourhoods['Latitude'] = lat
Neighbourhoods['Longitude'] = long
Neighbourhoods
# Out:
#             WijkenEnBuurten SoortRegio_2 Codering_3  AantalInwoners_5  \
# 0              Wijk 01 West         Wijk   WK034401             29270
# 1         Wijk 02 Noordwest         Wijk   WK034402             45255
# 2         Wijk 03 Overvecht         Wijk   WK034403             34295
# 3         Wijk 04 Noordoost         Wijk   WK034404             39680
# 4              Wijk 05 Oost         Wijk   WK034405             32080
# 5        Wijk 06 Binnenstad         Wijk   WK034406             19165
# 6              Wijk 07 Zuid         Wijk   WK034407             27895
# 7          Wijk 08 Zuidwest         Wijk   WK034408             38620
# 8     Wijk 09 Leidsche Rijn         Wijk   WK034409             41290
# 9  Wijk 10 Vleuten-De Meern         Wijk   WK034410             49795
#
#    Mannen_6  Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  k_25Tot45Jaar_10  \
# 0     14210      15055            4600             4215             12025
# 1     22060      23195            6240             6390             19595
# 2     17200      17095            6425             4410             11095
# 3     18780      20895            6215             6585             13480
# 4     14905      17170            3450             8270             11270
# 5      9815       9345             950             3255              9275
# 6     13685      14210            4445             4105             10265
# 7     19430      19190            6095             5730             15565
# 8     20685      20605           10170             4045             15755
# 9     24465      25330           11890             5660             12865
#
#    k_45Tot65Jaar_11  ...  OppervlakteWater_112  MateVanStedelijkheid_115  \
# 0              5720  ...                    88                       1.0
# 1              8545  ...                    14                       1.0
# 2              7490  ...                    30                       1.0
# 3              9140  ...                     9                       1.0
# 4              5835  ...                    30                       1.0
# 5              3635  ...                    11                       1.0
# 6              6090  ...                    14                       1.0
# 7              7245  ...                    49                       1.0
# 8              8705  ...                    79                       2.0
# 9             13430  ...                   214                       2.0
#
#    Omgevingsadressendichtheid_116     Neighbourhood  Price_2019Q3  \
# 0                          3707.0              West       341.181
# 1                          4030.0         Noordwest       309.690
# 2                          3276.0         Overvecht       274.954
# 3                          4531.0         Noordoost       445.016
# 4                          3545.0              Oost       507.770
# 5                          5642.0        Binnenstad       434.747
# 6                          3263.0              Zuid       327.887
# 7                          3555.0          Zuidwest       313.324
# 8                          1958.0     Leidsche rijn       415.235
# 9                          1501.0  Vleuten-De Meern       428.002
#
#    Price_per_m2  children_density  square_meters_2019  Latitude  Longitude
# 0         4.219          0.157157           80.867741   52.1091     5.0668
# 1         4.015          0.137885           77.133250   52.1108     5.0902
# 2         2.908          0.187345           94.550894   52.1180     5.1080
# 3         4.788          0.156628           92.944027   52.1035     5.1351
# 4         4.887          0.107544          103.902189   52.0840     5.1547
# 5         5.091          0.049570           85.395207   52.0889     5.1175
# 6         3.802          0.159348           86.240663   52.0641     5.1245
# 7         3.661          0.157820           85.584267   52.0758     5.1003
# 8         3.673          0.246307          113.050640   52.0954     5.0457
# 9         3.562          0.238779          120.157777   52.1002     5.0021
#
# [10 rows x 120 columns]

# %% [markdown]
# # Foursquare setup to iniate API calls using coordinates

# %%
CLIENT_ID = 'IGZLARW2W3UN1L3NRWFI5BEGNNTAXEGUWWOHTAKUNMCWVGRE' # your Foursquare ID
CLIENT_SECRET = 'RREOIBQAY4LI1SIT4TAGTIIJED0JVID3NPW3VTAFBK10QQSI' # your Foursquare Secret
ACCESS_TOKEN = 'V4HTSLLG3MVNCTAX2EYET5BDKWPMAIHHZ54QPEXGVQFJ2NGP' # removed
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IGZLARW2W3UN1L3NRWFI5BEGNNTAXEGUWWOHTAKUNMCWVGRE
# CLIENT_SECRET:RREOIBQAY4LI1SIT4TAGTIIJED0JVID3NPW3VTAFBK10QQSI

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# # Search for venues in each neighbourhood
# Limitation= radius is only 500m instead of the desired 2km due to api restrictions (max 100 venues per search).

# %%
utrecht_venues = getNearbyVenues(Neighbourhoods['Neighbourhood'], Neighbourhoods['Latitude'], Neighbourhoods['Longitude'], radius=500)
utrecht_venues
# Out:
# West
# Noordwest
# Overvecht
# Noordoost
# Oost
# Binnenstad
# Zuid
# Zuidwest
# Leidsche rijn
# Vleuten-De Meern
#         Neighbourhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0                West                52.1091                  5.0668
# 1                West                52.1091                  5.0668
# 2                West                52.1091                  5.0668
# 3           Noordwest                52.1108                  5.0902
# 4           Noordwest                52.1108                  5.0902
# ..                ...                    ...                     ...
# 163  Vleuten-De Meern                52.1002                  5.0021
# 164  Vleuten-De Meern                52.1002                  5.0021
# 165  Vleuten-De Meern                52.1002                  5.0021
# 166  Vleuten-De Meern                52.1002                  5.0021
# 167  Vleuten-De Meern                52.1002                  5.0021
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0                           fonQ       52.107630         5.061015
# 1            Bushalte Uraniumweg       52.109123         5.063746
# 2                    RoKa snacks       52.105730         5.066587
# 3                  IJssalon Roma       52.111163         5.089668
# 4                    Julianapark       52.107307         5.086733
# ..                           ...             ...              ...
# 163        Sporthal Weide Wereld       52.096014         5.002594
# 164              Station Vleuten       52.102871         5.007351
# 165  FLeiR Apotheek Vleuterweide       52.099495         5.005790
# 166           Busstation Vleuten       52.102898         5.007274
# 167                      Spoor 1       52.102909         5.007335
#
#              Venue Category
# 0    Furniture / Home Store
# 1                  Bus Stop
# 2                 Cafeteria
# 3            Ice Cream Shop
# 4                      Park
# ..                      ...
# 163      Athletics & Sports
# 164           Train Station
# 165                Pharmacy
# 166             Bus Station
# 167                Platform
#
# [168 rows x 7 columns]

# %% [markdown]
# # Group and add venues to existing dataset

# %%
utrecht_venues_grouped= utrecht_venues.groupby(['Neighbourhood'])['Venue']
utrecht_venues_grouped.count()

Neighbourhoods = pd.merge(Neighbourhoods, utrecht_venues_grouped.count(), how='left', left_on='Neighbourhood', right_on='Neighbourhood')
Neighbourhoods
# Out:
#             WijkenEnBuurten SoortRegio_2 Codering_3  AantalInwoners_5  \
# 0              Wijk 01 West         Wijk   WK034401             29270
# 1         Wijk 02 Noordwest         Wijk   WK034402             45255
# 2         Wijk 03 Overvecht         Wijk   WK034403             34295
# 3         Wijk 04 Noordoost         Wijk   WK034404             39680
# 4              Wijk 05 Oost         Wijk   WK034405             32080
# 5        Wijk 06 Binnenstad         Wijk   WK034406             19165
# 6              Wijk 07 Zuid         Wijk   WK034407             27895
# 7          Wijk 08 Zuidwest         Wijk   WK034408             38620
# 8     Wijk 09 Leidsche Rijn         Wijk   WK034409             41290
# 9  Wijk 10 Vleuten-De Meern         Wijk   WK034410             49795
#
#    Mannen_6  Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  k_25Tot45Jaar_10  \
# 0     14210      15055            4600             4215             12025
# 1     22060      23195            6240             6390             19595
# 2     17200      17095            6425             4410             11095
# 3     18780      20895            6215             6585             13480
# 4     14905      17170            3450             8270             11270
# 5      9815       9345             950             3255              9275
# 6     13685      14210            4445             4105             10265
# 7     19430      19190            6095             5730             15565
# 8     20685      20605           10170             4045             15755
# 9     24465      25330           11890             5660             12865
#
#    k_45Tot65Jaar_11  ...  MateVanStedelijkheid_115  \
# 0              5720  ...                       1.0
# 1              8545  ...                       1.0
# 2              7490  ...                       1.0
# 3              9140  ...                       1.0
# 4              5835  ...                       1.0
# 5              3635  ...                       1.0
# 6              6090  ...                       1.0
# 7              7245  ...                       1.0
# 8              8705  ...                       2.0
# 9             13430  ...                       2.0
#
#    Omgevingsadressendichtheid_116     Neighbourhood  Price_2019Q3  \
# 0                          3707.0              West       341.181
# 1                          4030.0         Noordwest       309.690
# 2                          3276.0         Overvecht       274.954
# 3                          4531.0         Noordoost       445.016
# 4                          3545.0              Oost       507.770
# 5                          5642.0        Binnenstad       434.747
# 6                          3263.0              Zuid       327.887
# 7                          3555.0          Zuidwest       313.324
# 8                          1958.0     Leidsche rijn       415.235
# 9                          1501.0  Vleuten-De Meern       428.002
#
#    Price_per_m2  children_density  square_meters_2019  Latitude  Longitude  \
# 0         4.219          0.157157           80.867741   52.1091     5.0668
# 1         4.015          0.137885           77.133250   52.1108     5.0902
# 2         2.908          0.187345           94.550894   52.1180     5.1080
# 3         4.788          0.156628           92.944027   52.1035     5.1351
# 4         4.887          0.107544          103.902189   52.0840     5.1547
# 5         5.091          0.049570           85.395207   52.0889     5.1175
# 6         3.802          0.159348           86.240663   52.0641     5.1245
# 7         3.661          0.157820           85.584267   52.0758     5.1003
# 8         3.673          0.246307          113.050640   52.0954     5.0457
# 9         3.562          0.238779          120.157777   52.1002     5.0021
#
#    Venue
# 0      3
# 1     16
# 2      8
# 3      9
# 4      5
# 5    100
# 6      5
# 7     12
# 8      4
# 9      6
#
# [10 rows x 121 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


X1=Neighbourhoods[['Omgevingsadressendichtheid_116', 'Price_2019Q3', 'square_meters_2019', 'Venue', 'children_density']]

scaler = StandardScaler()
scaled_features = scaler.fit_transform(X1)

scaled_features
# Out:
# array([[ 0.18472648, -0.536617  , -0.97519031, -0.49305843, -0.04905514],
#        [ 0.4740895 , -0.97440926, -1.25287695, -0.0285831 , -0.40172339],
#        [-0.20138949, -1.45731396,  0.04225194, -0.31441407,  0.50335796],
#        [ 0.92291572,  0.9069116 , -0.07723037, -0.2786852 , -0.05874418],
#        [ 0.03959704,  1.77932643,  0.73758898, -0.42160069, -0.95695607],
#        [ 1.91821699,  0.76415053, -0.63854018,  2.97264214, -2.01784416],
#        [-0.21303568, -0.72143204, -0.57567439, -0.42160069, -0.00897859],
#        [ 0.04855565, -0.92388889, -0.62448223, -0.17149859, -0.03693579],
#        [-1.38213393,  0.492892  ,  1.41784301, -0.45732956,  1.58231491],
#        [-1.79154228,  0.67038061,  1.94631048, -0.38587182,  1.44456446]])

# %%
kmeans = KMeans(
n_clusters=4,
n_init=10,
max_iter=500,
random_state=2)

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(max_iter=500, n_clusters=4, random_state=2)

# %%
print(kmeans.cluster_centers_)
print(kmeans.labels_)
# Out:
# [[ 4.81256382e-01  1.34311901e+00  3.30179308e-01 -3.50142945e-01
#   -5.07850128e-01]
#  [ 5.85892915e-02 -9.22732233e-01 -6.77194388e-01 -2.85830975e-01
#    1.33301008e-03]
#  [-1.58683810e+00  5.81636302e-01  1.68207675e+00 -4.21600688e-01
#    1.51343968e+00]
#  [ 1.91821699e+00  7.64150534e-01 -6.38540176e-01  2.97264214e+00
#   -2.01784416e+00]]
# [1 1 1 0 0 3 1 1 2 2]

# %%
Neighbourhoods
# Out:
#             WijkenEnBuurten SoortRegio_2 Codering_3  AantalInwoners_5  \
# 0              Wijk 01 West         Wijk   WK034401             29270
# 1         Wijk 02 Noordwest         Wijk   WK034402             45255
# 2         Wijk 03 Overvecht         Wijk   WK034403             34295
# 3         Wijk 04 Noordoost         Wijk   WK034404             39680
# 4              Wijk 05 Oost         Wijk   WK034405             32080
# 5        Wijk 06 Binnenstad         Wijk   WK034406             19165
# 6              Wijk 07 Zuid         Wijk   WK034407             27895
# 7          Wijk 08 Zuidwest         Wijk   WK034408             38620
# 8     Wijk 09 Leidsche Rijn         Wijk   WK034409             41290
# 9  Wijk 10 Vleuten-De Meern         Wijk   WK034410             49795
#
#    Mannen_6  Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  k_25Tot45Jaar_10  \
# 0     14210      15055            4600             4215             12025
# 1     22060      23195            6240             6390             19595
# 2     17200      17095            6425             4410             11095
# 3     18780      20895            6215             6585             13480
# 4     14905      17170            3450             8270             11270
# 5      9815       9345             950             3255              9275
# 6     13685      14210            4445             4105             10265
# 7     19430      19190            6095             5730             15565
# 8     20685      20605           10170             4045             15755
# 9     24465      25330           11890             5660             12865
#
#    k_45Tot65Jaar_11  ...  Omgevingsadressendichtheid_116     Neighbourhood  \
# 0              5720  ...                          3707.0              West
# 1              8545  ...                          4030.0         Noordwest
# 2              7490  ...                          3276.0         Overvecht
# 3              9140  ...                          4531.0         Noordoost
# 4              5835  ...                          3545.0              Oost
# 5              3635  ...                          5642.0        Binnenstad
# 6              6090  ...                          3263.0              Zuid
# 7              7245  ...                          3555.0          Zuidwest
# 8              8705  ...                          1958.0     Leidsche rijn
# 9             13430  ...                          1501.0  Vleuten-De Meern
#
#    Price_2019Q3  Price_per_m2  children_density  square_meters_2019  Latitude  \
# 0       341.181         4.219          0.157157           80.867741   52.1091
# 1       309.690         4.015          0.137885           77.133250   52.1108
# 2       274.954         2.908          0.187345           94.550894   52.1180
# 3       445.016         4.788          0.156628           92.944027   52.1035
# 4       507.770         4.887          0.107544          103.902189   52.0840
# 5       434.747         5.091          0.049570           85.395207   52.0889
# 6       327.887         3.802          0.159348           86.240663   52.0641
# 7       313.324         3.661          0.157820           85.584267   52.0758
# 8       415.235         3.673          0.246307          113.050640   52.0954
# 9       428.002         3.562          0.238779          120.157777   52.1002
#
#    Longitude  Venue  cluster
# 0     5.0668      3        1
# 1     5.0902     16        1
# 2     5.1080      8        1
# 3     5.1351      9        0
# 4     5.1547      5        0
# 5     5.1175    100        3
# 6     5.1245      5        1
# 7     5.1003     12        1
# 8     5.0457      4        2
# 9     5.0021      6        2
#
# [10 rows x 122 columns]
